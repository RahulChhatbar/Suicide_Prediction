# %%
import joblib
import warnings
warnings.filterwarnings("ignore")
import nltk
import re
import pickle
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import pos_tag, WordNetLemmatizer
from nltk.corpus import wordnet

# Initialize
lemmatizer = WordNetLemmatizer()
stopwords_set = set(stopwords.words('english'))
negation_words = [
    "not", "no", "never", "nothing", "nobody", "neither", "nowhere", "cannot", 
    "can't", "won't", "don't", "doesn't", "didn't", "hasn't", "haven't", 
    "hadn't", "isn't", "aren't", "wasn't", "weren't", "without", "none", 
    "naught", "naughtiness", "less"
]

best_model_lr = joblib.load('../Models/logistic_regression_model.pkl')
best_model_mnb = joblib.load('../Models/multinomial_naive_bayes_model.pkl')
best_model_knn = joblib.load('../Models/k_nearest_neighbors_model.pkl')
best_model_rf = joblib.load('../Models/random_forest_model.pkl')
vectorizer = joblib.load('../Models/vectorizer.pkl')

models = {
    'Logistic Regression': best_model_lr,
    'Multinomial Naive Bayes': best_model_mnb,
    'K-Nearest Neighbors': best_model_knn,
    'Random Forest': best_model_rf
}

# random_text = "Do you ever alone, isolated, uncared for?"
# random_text2 = "Today's fact is Reddit awards are expensive."
# random_text_list = [random_text]
# random_text_list2 = [random_text2]
# random_text_transformed = vectorizer.transform(random_text_list)
# random_text_transformed2 = vectorizer.transform(random_text_list2)

# prediction_lr = best_model_lr.predict(random_text_transformed)
# prediction_mnb = best_model_mnb.predict(random_text_transformed)
# prediction_knn = best_model_knn.predict(random_text_transformed)
# prediction_rf = best_model_rf.predict(random_text_transformed)
# prediction_lr2 = best_model_lr.predict(random_text_transformed2)
# prediction_mnb2 = best_model_mnb.predict(random_text_transformed2)
# prediction_knn2 = best_model_knn.predict(random_text_transformed2)
# prediction_rf2 = best_model_rf.predict(random_text_transformed2)

# print("Prediction of first test string:", random_text)
# print("Prediction using Logistic Regression of first test:", prediction_lr[0])
# print("Prediction using Multinomial Naive Bayes of first test:", prediction_mnb[0])
# print("Prediction using K Nearest Neighbors of first test:", prediction_knn[0])
# print("Prediction using Random Forest of first test:", prediction_rf[0])
# print("\nPrediction of second test string:", random_text2)
# print("Prediction using Logistic Regression of second test:", prediction_lr2[0])
# print("Prediction using Multinomial Naive Bayes of second test:", prediction_mnb2[0])
# print("Prediction using K Nearest Neighbors of second test:", prediction_knn2[0])
# print("Prediction using Random Forest of second test:", prediction_rf2[0])

# %%
def preprocess_and_predict(input_string, models, vectorizer):
    # Preprocess the text
    def preprocess_text(text):
        text = re.sub(r'(?<=[a-z])(?=[A-Z])', ' ', text)
        text = text.lower()
        text = re.sub(r'[^\w\s]', '', text)
        text = re.sub(r'\d+', '', text)
        words = word_tokenize(text)
        processed_words = []
        negation = False
        negation_word = ''
        for word in words:
            if word in negation_words:
                negation = True
                negation_word = word
            elif negation:
                if word.isdigit():
                    processed_words.append(negation_word)
                    processed_words.append(word)
                else:
                    processed_words.append(f'not_{word}')
                negation = False
                negation_word = ''
            else:
                processed_words.append(word)
        processed_words = [word for word in processed_words if word not in stopwords_set]
        lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in processed_words]
        return ' '.join(lemmatized_words)

    def get_wordnet_pos(word):
        tag = pos_tag([word])[0][1][0].upper()
        tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
        return tag_dict.get(tag, wordnet.NOUN)

    # Preprocess the input string
    processed_string = preprocess_text(input_string)
    
    # Transform the processed string using the vectorizer
    vectorized_input = vectorizer.transform([processed_string])
    
    # Predict using all models
    predictions = {model_name: model.predict(vectorized_input) for model_name, model in models.items()}
    
    return predictions

# %%
test_string = "Do you ever alone, isolated, uncared for?"
results = preprocess_and_predict(test_string, models, vectorizer)
for model_name, prediction in results.items():
    print(f"Prediction using {model_name}: {prediction[0]}")
# Out:
# Prediction using Logistic Regression: non-suicide
# Prediction using Multinomial Naive Bayes: suicide
# Prediction using K-Nearest Neighbors: suicide
# Prediction using Random Forest: non-suicide
